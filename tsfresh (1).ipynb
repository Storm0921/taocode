# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import numpy as np
from tsfresh import extract_features, extract_relevant_features, select_features
#from tsfresh.feature_extraction import ComprehensiveFCParameters
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# C:\Anaconda\lib\site-packages\statsmodels\compat\pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %% [markdown]
# # https://tsfresh.readthedocs.io/en/latest/text/data_formats.html
# ### Input Option 1. Flat DataFrame or Wide DataFrame
#
# |id	|time	|x	|y|
# |---|---|---|---|
# |A	|t1	|x(A, t1)	|y(A, t1)|
# |A	|t2	|x(A, t2)	|y(A, t2)|
# |A	|t3	|x(A, t3)	|y(A, t3)|
# |B	|t1	|x(B, t1)	|y(B, t1)|
# |B	|t2	|x(B, t2)	|y(B, t2)|
# |B	|t3	|x(B, t3)	|y(B, t3)|
#
# ### Input Option 2. Stacked DataFrame or Long DataFrame
# ### Input Option 3. Dictionary of flat DataFrames

# %%
data = pd.read_csv('DB_TIME_HISTORY.csv')
data0 = data.groupby('INST_NAME').get_group('ACTDB11')

# %%
#输入某一个实例的数据data，输出处理后的时间与缺失值datanew
def time_miss_fix(data):
    time = data['SNAP_PERIOD']
    time = [i[:15] for i in time]
    time = pd.to_datetime(time,format = '%Y-%m-%d-%H%M')
    time = list(time)
    
    #时间取整
    for i in range(len(time)):
        if time[i].minute>0 and time[i].minute<30:
            time[i] = time[i] - datetime.timedelta(minutes=time[i].minute) #向下
            if time[i] == time[i-1]:
                time[i] = time[i] + datetime.timedelta(minutes=30) #向上
        elif time[i].minute>30:
            time[i] = time[i] - datetime.timedelta(minutes=(time[i].minute-30))
            if time[i] == time[i-1]:
                time[i] = time[i] + datetime.timedelta(minutes=30)
    
    time_new = pd.date_range(min(time),max(time),freq='1800s')
    datanew = pd.DataFrame(index=time_new,columns=['DB_TIME'])  #生成完整的时间
    datanew.loc[time,'DB_TIME']=list(data['DB_TIME'])                               #根据时间填充取值
    datanew.loc[datanew['DB_TIME']<0,'DB_TIME']=np.nan                     #把负值当成缺失值
    
    datanew.loc[datanew['DB_TIME']>100,'DB_TIME']=np.nan                #把大于100的当成缺失值
    
    return datanew

# %%
series = time_miss_fix(data0).DB_TIME

# %%
#把时间序列数据转换为监督学习数据,n_in是X的维度,n_out是Y的维度
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    #n_vars = 1 if type(data) is list else data.shape[0]
    df = pd.DataFrame(data)
    cols = list()
    # input sequence (t-n, ... t-1)  自变量X
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
    # forecast sequence (t, t+1, ... t+n)  因变量Y
    for i in range(0, n_out):
        cols.append(df.shift(-i))
    # put it all together  合并X和Y
    agg = pd.concat(cols, axis=1)
    # drop rows with NaN values  只要有缺失值，就删除那个样本
    if dropnan:
        agg.dropna(inplace=True)
    
    X = agg.values[:, :n_in]
    Y = agg.values[:,n_in:]
    
    return X, Y

# %%
dataX, dataY = series_to_supervised(series,48,1)

# %%
dataX.shape
# Out:
# (33932, 48)

# %%
df_dbtime = dataX.reshape(-1)
df_id = np.repeat(range(dataX.shape[0]),dataX.shape[1])
df_time = np.array(list(range(0,dataX.shape[1]))*dataX.shape[0])
df = np.array([df_dbtime,df_id,df_time]).T

# %%
df = pd.DataFrame(df,columns=['DB_TIME','id','time'])
df['DB_TIME'] = [np.float(i) for i in df['DB_TIME']] #好像要变成numpy格式的数值才能提取特征

# %%
df #共33932个子序列
# Out:
#          DB_TIME     id time
# 0          19.55      0    0
# 1          36.33      0    1
# 2          28.35      0    2
# 3          31.55      0    3
# 4          33.29      0    4
# ...          ...    ...  ...
# 1628731    21.02  33931   43
# 1628732     8.73  33931   44
# 1628733     6.86  33931   45
# 1628734     5.98  33931   46
# 1628735     5.58  33931   47
#
# [1628736 rows x 3 columns]

# %%
y = pd.Series(dataY.reshape(-1)) #y的id要与df对应
y
# Out:
# 0        15.92
# 1         15.4
# 2        13.83
# 3        21.87
# 4        13.83
#          ...
# 33927     8.73
# 33928     6.86
# 33929     5.98
# 33930     5.58
# 33931     5.23
# Length: 33932, dtype: object

# %%
#extraction_settings = ComprehensiveFCParameters() #可以设置要提取的特征
#X_feature = extract_features(df_new,column_id='id', column_sort='time') #提取特征，根据id聚合

#直接根据y提取过滤后的特征
X_filtered = extract_relevant_features(df, y, column_id='id', column_sort='time')
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 20/20 [09:42<00:00, 17.39s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0805a302357a> in <module>
#       3
#       4 #直接根据y提取过滤后的特征
# ----> 5 X_filtered = extract_relevant_features(df, y, column_id='id', column_sort='time')
#
# C:\Anaconda\lib\site-packages\tsfresh\convenience\relevant_extraction.py in extract_relevant_features(timeseries_container, y, X, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, show_warnings, disable_progressbar, profile, profiling_filename, profiling_sorting, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent, n_jobs, distributor, chunksize, ml_task)
#     181                             show_warnings=show_warnings,
#     182                             chunksize=chunksize,
# --> 183                             ml_task=ml_task)
#     184
#     185     if X is None:
#
# C:\Anaconda\lib\site-packages\tsfresh\feature_selection\selection.py in select_features(X, y, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent, n_jobs, show_warnings, chunksize, ml_task)
#     144         X, y, ml_task=ml_task, n_jobs=n_jobs, show_warnings=show_warnings, chunksize=chunksize,
#     145         test_for_binary_target_real_feature=test_for_binary_target_real_feature,
# --> 146         fdr_level=fdr_level, hypotheses_independent=hypotheses_independent,
#     147     )
#     148
#
# C:\Anaconda\lib\site-packages\tsfresh\feature_selection\relevance.py in calculate_relevance_table(X, y, ml_task, n_jobs, show_warnings, chunksize, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent)
#     188                 tmp = _calculate_relevance_table_for_implicit_target(
#     189                     table_real, table_binary, X, _test_real_feature, _test_binary_feature, hypotheses_independent,
# --> 190                     fdr_level, map_function
#     191                 )
#     192                 tables.append(tmp)
#
# C:\Anaconda\lib\site-packages\tsfresh\feature_selection\relevance.py in _calculate_relevance_table_for_implicit_target(table_real, table_binary, X, test_real_feature, test_binary_feature, hypotheses_independent, fdr_level, map_function)
#     219                                                    hypotheses_independent, fdr_level, map_function):
#     220     table_real['p_value'] = pd.Series(
# --> 221         map_function(test_real_feature, [X[feature] for feature in table_real.index]),
#     222         index=table_real.index
#     223     )
#
# C:\Anaconda\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# C:\Anaconda\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# C:\Anaconda\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# C:\Anaconda\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# C:\Anaconda\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
print(X_filtered.shape)
X_filtered

# %%
datanew = time_miss_fix(data0)

# %%
datanew
# Out:
#                     DB_TIME
# 2019-01-01 00:00:00   19.55
# 2019-01-01 00:30:00   36.33
# 2019-01-01 01:00:00   28.35
# 2019-01-01 01:30:00   31.55
# 2019-01-01 02:00:00   33.29
# ...                     ...
# 2020-12-21 11:30:00    8.73
# 2020-12-21 12:00:00    6.86
# 2020-12-21 12:30:00    5.98
# 2020-12-21 13:00:00    5.58
# 2020-12-21 13:30:00    5.23
#
# [34588 rows x 1 columns]

# %%
datanew['id'] = [str(i)[:10] for i in datanew.index]

# %%
datanew['time'] = list(range(0,48))*(len(datanew)//48)+list(range(len(datanew)%48))

# %%
datanew
# Out:
#                     DB_TIME          id  time
# 2019-01-01 00:00:00   19.55  2019-01-01     0
# 2019-01-01 00:30:00   36.33  2019-01-01     1
# 2019-01-01 01:00:00   28.35  2019-01-01     2
# 2019-01-01 01:30:00   31.55  2019-01-01     3
# 2019-01-01 02:00:00   33.29  2019-01-01     4
# ...                     ...         ...   ...
# 2020-12-21 11:30:00    8.73  2020-12-21    23
# 2020-12-21 12:00:00    6.86  2020-12-21    24
# 2020-12-21 12:30:00    5.98  2020-12-21    25
# 2020-12-21 13:00:00    5.58  2020-12-21    26
# 2020-12-21 13:30:00    5.23  2020-12-21    27
#
# [34588 rows x 3 columns]

# %%
datanew['DB_TIME'] = datanew['DB_TIME'].fillna(datanew['DB_TIME'].mean())

# %%
#特征提取（每一段子序列的特征）
#extraction_settings = ComprehensiveFCParameters() #可以设置要提取的特征
X = extract_features(datanew,column_id='id', column_sort='time') #根据id聚合
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 20/20 [00:27<00:00,  1.30it/s]

# %%
print(X.shape)
X
# Out:
# (721, 784)
#             DB_TIME__variance_larger_than_standard_deviation  \
# 2019-01-01                                               1.0
# 2019-01-02                                               1.0
# 2019-01-03                                               1.0
# 2019-01-04                                               1.0
# 2019-01-05                                               1.0
# ...                                                      ...
# 2020-12-17                                               1.0
# 2020-12-18                                               1.0
# 2020-12-19                                               1.0
# 2020-12-20                                               1.0
# 2020-12-21                                               1.0
#
#             DB_TIME__has_duplicate_max  DB_TIME__has_duplicate_min  \
# 2019-01-01                         0.0                         0.0
# 2019-01-02                         0.0                         0.0
# 2019-01-03                         0.0                         0.0
# 2019-01-04                         0.0                         0.0
# 2019-01-05                         0.0                         0.0
# ...                                ...                         ...
# 2020-12-17                         0.0                         0.0
columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 721 entries, 2019-01-01 to 2020-12-21
# Columns: 784 entries, DB_TIME__variance_larger_than_standard_deviation to DB_TIME__permutation_entropy__dimension_7__tau_1
# dtypes: float64(784)
# memory usage: 4.3+ MB

# %%
#特征过滤，根据预测值y来提取最相关的特征
y = pd.Series(datanew.loc[datanew['time']==0,'DB_TIME'],index=[str(i)[:10] for i in X.index])

# %%
y
# Out:
# 2019-01-01    19.55
# 2019-01-02    15.92
# 2019-01-03    28.21
# 2019-01-04    13.37
# 2019-01-05    10.88
#               ...
# 2020-12-17     9.29
# 2020-12-18     6.88
# 2020-12-19     8.32
# 2020-12-20     8.38
# 2020-12-21     8.28
# Name: DB_TIME, Length: 721, dtype: float64

# %%
#特征过滤
X_filtered = extract_relevant_features(datanew, y, column_id='id', column_sort='time')
print(X_filtered.shape)
X_filtered
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 20/20 [00:28<00:00,  1.04it/s]
# (721, 278)
#             DB_TIME__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)  \
# 2019-01-01                                          52.255022
# 2019-01-02                                          36.266985
# 2019-01-03                                          27.790206
# 2019-01-04                                          26.865565
# 2019-01-05                                          23.549264
# ...                                                       ...
# 2020-12-17                                          17.113184
# 2020-12-18                                          16.255600
# 2020-12-19                                          17.829323
# 2020-12-20                                          18.299108
# 2020-12-21                                          17.903441
#
#             DB_TIME__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)  \
# 2019-01-01                                          56.046387
# 2019-01-02                                          38.715427
# 2019-01-03                                          29.695661
# 2019-01-04                                          28.659286
# 2019-01-05                                          25.152855
# ...                                                       ...
# 2020-12-17                                          18.498225
# 2020-12-18                                          18.004962
# 2020-12-19                                          19.188108
# 2020-12-20                                          19.670546
# 2020-12-21                                          19.284351
#
#             DB_TIME__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)  \
# 2019-01-01                                          58.572763
# 2019-01-02                                          41.004912
# 2019-01-03                                          31.951014
# 2019-01-04                                          30.411393
# 2019-01-05                                          26.684745
# ...                                                       ...
# 2020-12-17                                          19.894791
# 2020-12-18                                          19.797806
# 2020-12-19                                          20.547259
# 2020-12-20                                          21.053421
# 2020-12-21                                          20.409776
#
#             DB_TIME__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)  \
# 2019-01-01                                          62.386184
# 2019-01-02                                          43.244191
# 2019-01-03                                          33.967417
# 2019-01-04                                          32.068436
# 2019-01-05                                          28.254357
# ...                                                       ...
# 2020-12-17                                          21.246032
# 2020-12-18                                          21.559166
# 2020-12-19                                          21.865547
# 2020-12-20                                          22.416708
# 2020-12-21                                          21.524046
#
#             DB_TIME__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)  \
# 2019-01-01                                          66.006701
# 2019-01-02                                          45.368117
# 2019-01-03                                          36.122987
# 2019-01-04                                          33.604709
# 2019-01-05                                          29.790161
# ...                                                       ...
# 2020-12-17                                          22.556308
# 2020-12-18                                          23.305513
# 2020-12-19                                          23.137003
# 2020-12-20                                          23.752858
# 2020-12-21                                          22.553358
#
#             DB_TIME__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)  \
# 2019-01-01                                          68.535659
# 2019-01-02                                          47.326876
# 2019-01-03                                          38.092114
# 2019-01-04                                          35.056584
# 2019-01-05                                          31.145382
# ...                                                       ...
# 2020-12-17                                          23.682090
# 2020-12-18                                          24.860727
# 2020-12-19                                          24.203313
# 2020-12-20                                          24.932260
# 2020-12-21                                          23.929120
#
#             DB_TIME__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20
change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0  \
# 2019-01-01                                           5.112504
# 2019-01-02                                           1.722159
# 2019-01-03                                           8.340993
# 2019-01-04                                           1.005067
# 2019-01-05                                           2.568153
# ...                                                       ...
# 2020-12-17                                           2.114775
# 2020-12-18                                           3.001668
# 2020-12-19                                           2.194752
# 2020-12-20                                           3.009390
# 2020-12-21                                           6.216922
#
#             DB_TIME__fft_aggregated__aggtype_"variance"  \
# 2019-01-01                                    54.836819
# 2019-01-02                                    45.831545
# 2019-01-03                                    66.433882
# 2019-01-04                                    65.370884
# 2019-01-05                                    49.717390
# ...                                                 ...
# 2020-12-17                                    56.872811
# 2020-12-18                                    65.985087
# 2020-12-19                                    47.090593
# 2020-12-20                                    64.138794
# 2020-12-21                                    14.397574
#
#             DB_TIME__fft_aggregated__aggtype_"skew"  \
# 2019-01-01                                 0.756761
# 2019-01-02                                 1.303206
# 2019-01-03                                 0.686264
# 2019-01-04                                 1.503610
# 2019-01-05                                 1.475056
# ...                                             ...
# 2020-12-17                                 1.298065
# 2020-12-18                                 1.001216
# 2020-12-19                                 1.687410
# 2020-12-20                                 1.373829
# 2020-12-21                                 1.442264
#
#             DB_TIME__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2  \
# 2019-01-01                                           0.415372
# 2019-01-02                                           0.239024
# 2019-01-03                                           0.771865
# 2019-01-04                                           0.098852
# 2019-01-05                                           0.594605
# ...                                                       ...
# 2020-12-17                                           0.335729
# 2020-12-18                                           0.245541
# 2020-12-19                                           0.177046
# 2020-12-20                                           0.162517
# 2020-12-21                                           0.373336
#
#             DB_TIME__fft_coefficient__attr_"abs"__coeff_9  \
# 2019-01-01                                      45.863203
# 2019-01-02                                      27.381165
# 2019-01-03                                      28.470036
# 2019-01-04                                       6.995899
# 2019-01-05                                      26.357274
# ...                                                   ...
# 2020-12-17                                      10.588441
# 2020-12-18                                      18.395570
# 2020-12-19                                      11.793249
# 2020-12-20                                       7.271272
# 2020-12-21                                      13.051942
#
#             DB_TIME__index_mass_quantile__q_0.8  \
# 2019-01-01                             0.750000
# 2019-01-02                             0.750000
# 2019-01-03                             0.750000
# 2019-01-04                             0.791667
# 2019-01-05                             0.812500
# ...                                         ...
# 2020-12-17                             0.750000
# 2020-12-18                             0.750000
# 2020-12-19                             0.770833
# 2020-12-20                             0.729167
# 2020-12-21                             0.821429
#
#             DB_TIME__fft_coefficient__attr_"real"__coeff_14
# 2019-01-01                                       -24.445440
# 2019-01-02                                       -10.285762
# 2019-01-03                                        40.914892
# 2019-01-04                                         4.516097
# 2019-01-05                                         6.147681
# ...                                                     ...
# 2020-12-17                                         0.220067
# 2020-12-18                                         0.837100
# 2020-12-19                                         3.983189
# 2020-12-20                                        -4.072315
# 2020-12-21                                        13.700000
#
# [721 rows x 278 columns]

# %%
X_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 721 entries, 2019-01-01 to 2020-12-21
# Columns: 278 entries, DB_TIME__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20) to DB_TIME__fft_coefficient__attr_"real"__coeff_14
# dtypes: float64(278)
# memory usage: 1.5+ MB

# %%
X_train,X_test,X_filtered_train,X_filtered_test,y_train,y_test = train_test_split(X,X_filtered,y,test_size=0.3)

dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
print(classification_report(y_test, dtc.predict(X_test)))
dtc.n_features_

# %%
dtc2 = DecisionTreeClassifier()
dtc2.fit(X_filtered_train, y_train)
print(classification_report(y_test, dtc2.predict(X_filtered_test)))
dtc2.n_features_
